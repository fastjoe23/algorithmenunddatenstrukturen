# %% [markdown]
# # Bild Generierung
# Mithilfe des Codes innerhalb dieses Notebooks wurden einige der Grafiken in den anderen Notebooks erstellt.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import FancyArrowPatch
import numpy as np

# %% [markdown]
# # Heron Verfahren Quadrate

# %%
# Heron-Algorithmus Iterationsschritte visualisieren
n = 22  # Wir berechnen sqrt(10)
iterations = 3

# Starte mit einer ersten Schätzung
x_values = [n / 2]

# Berechne die nächsten Iterationen
for i in range(iterations - 1):
    x_next = (x_values[-1] + n / x_values[-1]) / 2
    x_values.append(x_next)

# Erstelle Subplot für jede Iteration
fig, axes = plt.subplots(1, iterations, figsize=(15, 5))

for idx, x in enumerate(x_values):
    ax = axes[idx]
    
    # Die andere Dimension des Rechtecks
    y = n / x
    
    # Zeichne das Rechteck
    rect = patches.Rectangle((0, 0), x, y, linewidth=2, edgecolor='blue', facecolor='lightblue', alpha=0.7)
    ax.add_patch(rect)
    
    # Zeichne die Diagonale zum Quadrat (sqrt(n) x sqrt(n))
    sqrt_n = np.sqrt(n)
    square = patches.Rectangle((0, 0), sqrt_n, sqrt_n, linewidth=2, edgecolor='green', 
                               facecolor='none', linestyle='--', label='Zielquadrat')
    ax.add_patch(square)
    
    # Achsen einstellen
    ax.set_xlim(-0.5, max(x, np.sqrt(n)) + 1)
    ax.set_ylim(-0.5, max(y, np.sqrt(n)) + 1)
    ax.set_aspect('equal')
    ax.grid(True, alpha=0.3)
    
    # Labels
    ax.set_xlabel(f'Breite: {x:.2f}', fontsize=10)
    ax.set_ylabel(f'Höhe: {y:.2f}', fontsize=10)
    ax.set_title(f'Iteration {idx + 1}\nx = {x:.2f}', fontsize=12, fontweight='bold')
    
    # Fläche des Rechtecks
    area = x * y
    ax.text(0.3, 0.2, f'Fläche={x:.2f} * {y:.2f} = {area:.2f})', 
            transform=ax.transAxes, ha='center', fontsize=9, 
            bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    if idx == 0:
        ax.legend(loc='upper right', fontsize=9)

plt.suptitle(f'Heron-Verfahren: Berechnung von √{n} durch iteratives Umwandeln des Rechtecks in ein Quadrat', 
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('heron_iterations.png', bbox_inches='tight')
plt.show()

# Ausgabe der Konvergenz
print(f"Konvergenz der Heron-Iterationen für √{n}:")
print(f"Zielwert: {np.sqrt(n):.10f}")
print()
for idx, x in enumerate(x_values):
    y = n / x
    error = abs(x - np.sqrt(n))
    print(f"Iteration {idx + 1}: x = {x:.10f}, Fehler = {error:.2e}")
# Out:
# Konvergenz der Heron-Iterationen für √22:
# Zielwert: 4.6904157598
#
# Iteration 1: x = 11.0000000000, Fehler = 6.31e+00
# Iteration 2: x = 6.5000000000, Fehler = 1.81e+00
# Iteration 3: x = 4.9423076923, Fehler = 2.52e-01

# %% [markdown]
# # Array Indexing Image

# %%
# Werte und Indizes
values = ['10', '23', '5', '42', '7', '31']
indices = list(range(len(values)))

fig, ax = plt.subplots(figsize=(8, 2.5))
ax.set_xlim(-2.5, 5.5)
ax.set_ylim(-2, 2.2)
ax.axis('off')

# Array-Zellen zeichnen
for i, val in enumerate(values):
    rect = patches.Rectangle((i, 0), 1, 1, fill=True, edgecolor='black', facecolor='#cce6ff')
    ax.add_patch(rect)
    ax.text(i+0.5, 0.5, val, va='center', ha='center', fontsize=14)
    ax.text(i+0.5, -0.2, f"Index {i}", va='center', ha='center', fontsize=10)

# Beispiel: Index 3 hervorheben
ax.add_patch(patches.Rectangle((3, 0), 1, 1, fill=False, edgecolor='red', linewidth=2))
ax.annotate("Direkter Zugriff per Offset-Berechnung", xy=(3.5, 1.2), xytext=(3.5, 1.7),
            arrowprops=dict(arrowstyle="->", color='red'), ha='center', fontsize=12, color='red')

# h-Linien und Beschriftungen zeichnen
for i in range(len(values)):
    x_start = i
    x_end = i+1
    y = -0.7
    ax.plot([x_start, x_end], [y, y], color='black', linewidth=2)
    ax.plot([x_start, x_start], [y+0.1, y-0.1], color='black', linewidth=2)
    ax.text((x_start+x_end)/2, y-0.1, "h", ha='center', va='top', fontsize=11)
ax.text(0, -1.0, "b = base adress", ha='center', va='top', fontsize=12)
plt.title("Array-Indexierung in Python", fontsize=16)

# Pfeil am Start von Index 3 mit Beschriftung
ax.annotate("", xy=(3, -1.5), xytext=(0, -1.5),
            arrowprops=dict(arrowstyle="->", color='blue', linewidth=2))
ax.text(1.5, -1.6, "b + 3 * h", ha='center', va='top', fontsize=12, color='blue')
plt.savefig('array_indexing.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Linked Structures

# %%
# Beispielwerte für die LinkedList
values = ['A', 'B', 'C', 'D']

fig, ax = plt.subplots(figsize=(9, 2.5))
ax.set_xlim(-1, len(values)*2)
ax.set_ylim(-1, 2)
ax.axis('off')

node_radius = 0.4
y = 1

# Nodes (Kreise) zeichnen
node_positions = []
for i, val in enumerate(values):
    x = i * 2
    node_positions.append((x, y))
    circle = plt.Circle((x, y), node_radius, color='#cce6ff', ec='black', zorder=10)
    ax.add_patch(circle)
    ax.text(x, y, val, ha='center', va='center', fontsize=14, zorder=11)
    ax.text(x, y-0.6, f"node{i}", ha='center', va='center', fontsize=10, zorder=11)

# Gebogene Pfeile zwischen den Nodes
for i in range(len(values)-1):
    x_start, y_start = node_positions[i][0]+node_radius, node_positions[i][1]
    x_end, y_end = node_positions[i+1][0]-node_radius, node_positions[i+1][1]
    arrow = FancyArrowPatch((x_start, y_start), (x_end, y_end),
                            connectionstyle="arc3,rad=-0.3",
                            arrowstyle='Simple,tail_width=0.5,head_width=8,head_length=8', lw=2, color='#5555cc', zorder=12)
    ax.add_patch(arrow)

# Head-Beschriftung
ax.text(node_positions[0][0], node_positions[0][1]+0.7, "head", ha='center', va='center', fontsize=12, color='#2222aa', fontweight='bold')



plt.text(len(values)*0.7, 1.8, "Linked List (verkettete Liste)", fontsize=14, ha='center')
plt.tight_layout()
plt.savefig("linked_list_visualization.png")
plt.show()

# %%
# Jetzt mit Tail
# Beispielwerte für die LinkedList
values = ['A', 'B', 'C', 'D']

fig, ax = plt.subplots(figsize=(9, 2.5))
ax.set_xlim(-1, len(values)*2)
ax.set_ylim(-1, 2)
ax.axis('off')

node_radius = 0.4
y = 1

# Nodes (Kreise) zeichnen
node_positions = []
for i, val in enumerate(values):
    x = i * 2
    node_positions.append((x, y))
    circle = plt.Circle((x, y), node_radius, color='#cce6ff', ec='black', zorder=10)
    ax.add_patch(circle)
    ax.text(x, y, val, ha='center', va='center', fontsize=14, zorder=11)
    ax.text(x, y-0.6, f"node{i}", ha='center', va='center', fontsize=10, zorder=11)

# Gebogene Pfeile zwischen den Nodes
for i in range(len(values)-1):
    x_start, y_start = node_positions[i][0]+node_radius, node_positions[i][1]
    x_end, y_end = node_positions[i+1][0]-node_radius, node_positions[i+1][1]
    arrow = FancyArrowPatch((x_start, y_start), (x_end, y_end),
                            connectionstyle="arc3,rad=-0.3",
                            arrowstyle='Simple,tail_width=0.5,head_width=8,head_length=8', lw=2, color='#5555cc', zorder=12)
    ax.add_patch(arrow)

# Head-Beschriftung
ax.text(node_positions[0][0], node_positions[0][1]+0.7, "head", ha='center', va='center', fontsize=12, color='#2222aa', fontweight='bold')
# Tail Beschriftung
ax.text(node_positions[-1][0], node_positions[-1][1]+0.7, "tail", ha='center', va='center', fontsize=12, color='#aa2222', fontweight='bold')
    

plt.text(len(values)*0.7, 1.8, "Linked List (verkettete Liste)", fontsize=14, ha='center')
plt.tight_layout()
plt.savefig("linked_list_visualization_with_tail.png")
plt.show()

# %%
# Doppelt verlinkte Liste


# Beispielwerte für die doppelt verkettete Liste
values = ['A', 'B', 'C', 'D','E']#, 'F', 'G']

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_xlim(-4, 4)
ax.set_ylim(-2.5, 4)
ax.axis('off')
arrow_style='Simple,tail_width=0.4,head_width=6,head_length=6'

# Kreis-Koordinaten für die Listenknoten
n = len(values)
radius = 1.5
angles = np.linspace(0, 2 * np.pi, n, endpoint=False)+0.125*np.pi
node_positions = [(radius * np.sin(a), radius * np.cos(a)) for a in angles]

# Sentinel-Node (head) oben platzieren
head_x, head_y = 0, radius + 1
head_radius = 0.45

# head zeichnen
head_circle = plt.Circle((head_x, head_y), head_radius, color='#ffd699', ec='black', zorder=10)
ax.add_patch(head_circle)
ax.text(head_x, head_y, "head\n + \n tail", ha='center', va='center', fontsize=11, zorder=11, fontweight='bold')

# Listenknoten zeichnen
node_radius = 0.32
for i, (x, y) in enumerate(node_positions):
    circle = plt.Circle((x, y), node_radius, color='#cce6ff', ec='black', zorder=10)
    ax.add_patch(circle)
    ax.text(x, y, values[i], ha='center', va='center', fontsize=12, zorder=11)

# next-Pfeile (im Kreis, mit head)
for i in range(n-1):
    start = node_positions[i]
    end = node_positions[(i+1)%n]
    arrow = FancyArrowPatch(
        (start[0]+node_radius*np.cos(angles[i]), start[1]-node_radius*np.sin(angles[i])),
        (end[0]-node_radius*np.cos(angles[(i+1)%n]), end[1]+node_radius*np.sin(angles[(i+1)%n])),
        connectionstyle="arc3,rad=-0.3", arrowstyle=arrow_style, lw=1, color='#5555cc', zorder=12)
    ax.add_patch(arrow)


# prior-Pfeile (gegen den Uhrzeigersinn)
for i in range(1,n):
    start = node_positions[i]
    end = node_positions[(i-1)%n]
    arrow = FancyArrowPatch(
        (start[0]-node_radius*np.cos(angles[i]), start[1]+node_radius*np.sin(angles[i])),
        (end[0]+node_radius*np.cos(angles[(i-1)%n]), end[1]-node_radius*np.sin(angles[(i-1)%n])),
        connectionstyle="arc3,rad=-0.3", arrowstyle=arrow_style, lw=1, color='#cc3333', zorder=12)
    ax.add_patch(arrow)

# head mit erstem und letztem Knoten verbinden (next und prior)
# head -> erster Knoten (next)
first_angle = angles[0]
first_x, first_y = node_positions[0]
arrow_head_next = FancyArrowPatch(
    (head_x, head_y-head_radius),
    (first_x, first_y+node_radius),
    connectionstyle="arc3,rad=0.2", arrowstyle=arrow_style, lw=1, color='#5555cc', zorder=12)
ax.add_patch(arrow_head_next)
# letzter Knoten -> head (next)
last_angle = angles[-1]
last_x, last_y = node_positions[-1]
arrow_last_next = FancyArrowPatch(
    (last_x, last_y+node_radius),
    (head_x, head_y-head_radius),
    connectionstyle="arc3,rad=-0.2", arrowstyle=arrow_style, lw=1, color='#5555cc', zorder=12)
ax.add_patch(arrow_last_next)
# head <- erster Knoten (prior)
arrow_head_prior = FancyArrowPatch(
    (first_x, first_y+node_radius),
    (head_x, head_y-head_radius),
    connectionstyle="arc3,rad=0.2", arrowstyle=arrow_style, lw=1, color='#cc3333', zorder=12)
ax.add_patch(arrow_head_prior)
# letzter Knoten <- head (prior)
arrow_last_prior = FancyArrowPatch(
    (head_x, head_y-head_radius),
    (last_x, last_y+node_radius),
    connectionstyle="arc3,rad=-0.2", arrowstyle=arrow_style, lw=1, color='#cc3333', zorder=12)
ax.add_patch(arrow_last_prior)


plt.text(0, 3.2, "Doppelt verkettete, zirkuläre Liste mit Sentinel-Node", fontsize=13, ha='center')
# Legende erzeugen
next_label_arrow = FancyArrowPatch(
    (2, 2.5), (2.5, 2.5),
    arrowstyle=arrow_style, lw=1, color='#5555cc', zorder=12)
ax.add_patch(next_label_arrow)
ax.text(2.7, 2.5, "next", fontsize=12, va='center', ha='left')
prior_label_arrow = FancyArrowPatch(
    (2.5, 2.2), (2, 2.2),
    arrowstyle=arrow_style, lw=1, color='#cc3333', zorder=12)
ax.add_patch(prior_label_arrow)
ax.text(2.7, 2.2, "previous", fontsize=12, va='center', ha='left')
plt.tight_layout()
plt.savefig("doubly_linked_circular_list_with_sentinel.png")
plt.show()

# %% [markdown]
# # Hash Tables

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

n_buckets = 7
bucket_distance = 1.6  # Abstand zwischen den Buckets
bucket_positions = [i * bucket_distance for i in range(n_buckets)]

beispielpaare = [(12, 'A'), (7, 'B'), (8, 'C')]
farben = ['#cce6ff', '#ffd699', '#c1f0c1', '#f0b3ff']

fig, ax = plt.subplots(figsize=(11, 3))
ax.set_xlim(-1, bucket_positions[-1] + 1)
ax.set_ylim(-2, 2)
ax.axis('off')

# Buckets zeichnen
for i, xpos in enumerate(bucket_positions):
    rect = patches.Rectangle((xpos, 0), 1, 1, fill=True, edgecolor='black', facecolor='#e6e6e6')
    ax.add_patch(rect)
    ax.text(xpos + 0.5, 0.5, f"Bucket {i}", va='center', ha='center', fontsize=11)

# Beispielhafte Einträge und Pfeile
for idx, (key, val) in enumerate(beispielpaare):
    bucket_idx = hash(key) % n_buckets
    xpos = bucket_positions[bucket_idx]
    if (-1)**idx >= 0:
        ax.text(xpos-0.3, (-1)**idx * 1.3, f"hash({key}) % {n_buckets}", ha='right', va='center', fontsize=12, color=farben[idx % len(farben)], bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=farben[idx % len(farben)], lw=2))
        ax.annotate("", xy=(xpos + 0.5, 1.05), xytext=(xpos-0.1, (-1)**idx * 1.3), arrowprops=dict(arrowstyle="->", color=farben[idx % len(farben)], lw=2))
    else:
        ax.text(xpos-0.3, (-1)**idx * 0.5, f"hash({key}) % {n_buckets}", ha='right', va='center', fontsize=12, color=farben[idx % len(farben)], bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=farben[idx % len(farben)], lw=2))
        ax.annotate("", xy=(xpos + 0.5, -.05), xytext=(xpos-0.1, (-1)**idx * 0.5), arrowprops=dict(arrowstyle="->", color=farben[idx % len(farben)], lw=2))
    
    ax.text(xpos + 0.5, 0.15, f"[{key}, {val}]", va='center', ha='center', fontsize=10, color="black")

ax.text(bucket_positions[-1] / 2, 1.8, "Hashtabelle mit Buckets", ha='center', fontsize=14)
plt.savefig('hash_table_buckets.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

n_buckets = 7
bucket_distance = 1.6  # Abstand zwischen den Buckets
bucket_positions = [i * bucket_distance for i in range(n_buckets)]

# Wir wählen Keys so, dass 12 und 8 auf Bucket 2 kollidieren:
beispielpaare = [(7, 'B'),(12, 'A'), (8, 'C')]
farben = ['#cce6ff', '#ffd699', '#c1f0c1']

fig, ax = plt.subplots(figsize=(11, 4))
ax.set_xlim(-1, bucket_positions[-1] + 1)
ax.set_ylim(-2, 2.2)
ax.axis('off')

# Buckets zeichnen
for i, xpos in enumerate(bucket_positions):
    rect = patches.Rectangle((xpos, 0), 1, 1, fill=True, edgecolor='black', facecolor='#e6e6e6')
    ax.add_patch(rect)
    ax.text(xpos + 0.5, 0.5, f"Bucket {i}", va='center', ha='center', fontsize=11)

# Einträge und Pfeile
# Key 7
ax.text(0.3, 1.3, f"hash({7}) % {n_buckets}", ha='right', va='center', fontsize=12, color=farben[0], bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=farben[0], lw=2))
ax.annotate("", xy=(bucket_positions[0] + .5, 1.05), xytext=(bucket_positions[0]+0.3, 1.3), arrowprops=dict(arrowstyle="->", color=farben[0], lw=2))
ax.text(bucket_positions[0] + 0.5, 0.15, f"[{7}, B]", va='center', ha='center', fontsize=10, color="black")
# Key 12 and 8 collide in Bucket 2
ax.text(bucket_positions[2] - 0.3, 1.3, f"hash({12}) % {n_buckets}", ha='right', va='center', fontsize=12, color=farben[1], bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=farben[1], lw=2))
ax.text(bucket_positions[2] + 2.5, 1.3, f"hash({8}) % {n_buckets}", ha='right', va='center', fontsize=12, color=farben[2], bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=farben[2], lw=2))
ax.annotate("", xy=(bucket_positions[2] + .5, 1.05), xytext=(bucket_positions[2]-0.2, 1.3), arrowprops=dict(arrowstyle="->", color=farben[1], lw=2))
ax.annotate("", xy=(bucket_positions[2] + .5, 1.05), xytext=(bucket_positions[2]+1.0, 1.3), arrowprops=dict(arrowstyle="->", color=farben[2], lw=2))
ax.text(bucket_positions[2] + 0.5, 0.15, f"Collision", va='center', ha='center', fontsize=10, color="black")

# Verkettete Liste für Bucket 2 zeichnen
x_bucket2 = bucket_positions[2] + 0.5
y_bucket = 0
node_radius = 0.4
# Knoten-Positionen für [12, 'A'] und [8, 'C']
knoten = [ (x_bucket2-0.35, y_bucket-0.7), (x_bucket2+0.75, y_bucket-0.7)]
for i, (key, val) in enumerate([(12, 'A'), (8, 'C')]):
    circle = plt.Circle(knoten[i], node_radius, color=farben[i+1], ec='black', zorder=10)
    ax.add_patch(circle)
    ax.text(knoten[i][0], knoten[i][1], f"{key}, {val}", ha='center', va='center', fontsize=10, zorder=11)
# Pfeil von Bucket nach erstem Knoten
ax.annotate("", xy=(x_bucket2, 0), xytext=knoten[0], arrowprops=dict(arrowstyle="->", lw=1.5, color='black'))
# Pfeil von erstem zu zweitem Knoten
ax.annotate("", xy=knoten[1], xytext=knoten[0], arrowprops=dict(arrowstyle="->", lw=1.5, color='black'))

ax.text(bucket_positions[-1] / 2, 2, "Hashtabelle mit Kollision und verketteter Liste", ha='center', fontsize=14)
plt.savefig('hash_table_collision.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Stack and Queue

# %%
def draw_stack(ax, values, xpos, label):
    y_base = 0
    width = 1
    height = 0.6
    for i, val in enumerate(values):
        y = y_base + i * height
        color = '#cce6ff'
        rect = plt.Rectangle((xpos, y), width, height, fill=True, edgecolor='black', facecolor=color, zorder=2)
        ax.add_patch(rect)
        ax.text(xpos + width/2, y + height/2, str(val), ha='center', va='center', fontsize=12, zorder=3)
    # Stack-Boden
    ax.plot([xpos, xpos+width], [y_base, y_base], color='black', linewidth=2, zorder=1)
    # Beschriftung unten
    #ax.text(xpos + width/2, -0.3, label, ha='center', va='top', fontsize=11)

steps = [
    [], ['Objekt 1'], ['Objekt 1', 'Objekt 2'], ['Objekt 1'], 
    ['Objekt 1', 'Objekt 3'], ['Objekt 1', 'Objekt 3', 'Objekt 4'], ['Objekt 1', 'Objekt 3'], []
]
actions = [
    "leer", "push('Objekt 1')", "push('Objekt 2')", "pop()", 
    "push('Objekt 3')", "push('Objekt 4')", "pop()", ""
]

fig, ax = plt.subplots(figsize=(14, 3.5))
ax.set_xlim(-0.5, len(steps)*1.5)
ax.set_ylim(-3, 2.8)
ax.axis('off')

# Stapel zeichnen
for i, (vals, act) in enumerate(zip(steps, actions)):
    draw_stack(ax, vals, i*1.8, act)

# Geschwungene Pfeile zwischen den Stapeln
for i in range(len(steps)-1):
    x1 = i*1.8 + 1
    x2 = (i+1)*1.8
    y = -1.6
    # Die Kurve nach oben für push, nach unten für pop
    if "push" in actions[i+1]:
        con = FancyArrowPatch((x1, y), (x2, y), connectionstyle="arc3,rad=-0.5", 
                              arrowstyle='Simple,tail_width=0.5,head_width=8,head_length=8',
                              color='#44aa44', lw=2)
        ax.add_patch(con)
        ax.text((x1+x2)/2, y+0.45, f"{actions[i+1]}", ha="center", va="bottom", color='#44aa44', fontsize=11)
    elif "pop" in actions[i+1]:
        con = FancyArrowPatch((x2, y), (x1, y), connectionstyle="arc3,rad=0.5", 
                              arrowstyle='Simple,tail_width=0.5,head_width=8,head_length=8', color='#cc3333', lw=2)
        ax.add_patch(con)
        ax.text((x1+x2)/2, y-0.2, "pop()", ha="center", va="top", color='#cc3333', fontsize=11)

plt.text(len(steps)*0.73, 2.5, "Stack (Stapel): LIFO-Prinzip)", fontsize=16, ha='center')
plt.text(len(steps)*0.73, -2.6, "(push = oben drauflegen, pop = oben wegnehmen)", fontsize=12, ha='center')
plt.tight_layout()
plt.savefig('stack_operations.png', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 2.7))
ax.set_xlim(-1, 6)
ax.set_ylim(0, 2.5)
ax.axis('off')

# Werte in der Queue
values = ['Objekt 3', 'Objekt 2', 'Objekt 1']

width = 1
height = 0.7
y = 1.2
x_base = 1
for i, val in enumerate(values):
    x = x_base + i * (width + 0.12)
    rect = plt.Rectangle((x, y), width, height, fill=True, edgecolor='black', facecolor='#cce6ff', zorder=2)
    ax.add_patch(rect)
    ax.text(x + width/2, y + height/2, str(val), ha='center', va='center', fontsize=12, zorder=3)

# dequeue-Pfeil (rechts)
x_deq = x_base
con_deq = FancyArrowPatch((x_deq-0.5, y + height/2), (x_deq, y + height/2),
                          connectionstyle="arc3,rad=-0.6",
                          arrowstyle='Simple,tail_width=0.5,head_width=8,head_length=8',
                          color='#44aa44', lw=2, zorder=5)
ax.add_patch(con_deq)
ax.text(x_deq-0.55, y + height/2, "enqueue", ha="right", va="center", color="#44aa44", fontsize=12)

# enqueue-Pfeil (links)
x_enq = x_base + (len(values)-1)*(width+0.12) + width
con_enq = FancyArrowPatch((x_enq, y + height/2), (x_enq+0.5, y + height/2),
                          connectionstyle="arc3,rad=-0.6",
                          arrowstyle='Simple,tail_width=0.5,head_width=8,head_length=8',
                          color='#cc3333', lw=2, zorder=5)
ax.add_patch(con_enq)
ax.text(x_enq+0.55, y + height/2, "dequeue", ha="left", va="center", color='#cc3333', fontsize=12)

# Titel
plt.text(2.5, 2.1, "Queue (Warteschlange): FIFO-Prinzip", fontsize=14, ha='center')
plt.text(4.1, 1, "Head", fontsize=11, ha='center')
plt.text(1.1, 1, "Tail", fontsize=11, ha='center')
plt.tight_layout()
plt.savefig("queue_visualization.png")
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(9, 5))
ax.set_xlim(-1, 7)
ax.set_ylim(-0.5, 5)
ax.axis('off')

# Werte für beide Queues
values_1 = ['Job 3', 'Job 2', 'Job 1']
values_2 = ['Job 1', 'Job 3', 'Job 2']

width = 1
height = 0.7
y1 = 3.2
y2 = 1.2
x_base = 1

# Zeichne erste Warteschlange
for i, val in enumerate(values_1):
    x = x_base + i * (width + 0.12)
    rect = plt.Rectangle((x, y1), width, height, fill=True, edgecolor='black', facecolor='#cce6ff', zorder=2)
    ax.add_patch(rect)
    ax.text(x + width/2, y1 + height/2, str(val), ha='center', va='center', fontsize=12, zorder=3)

# Gerade Pfeile für die erste Warteschlange
# Arriving jobs (links)
ax.arrow(x_base-1, y1+height/2, 0.9, 0, head_width=0.23, head_length=0.22, fc='#44aa44', ec='#44aa44', lw=2, length_includes_head=True)
ax.text(x_base-1.1, y1+height/2, "arriving jobs", ha="right", va="center", color="#44aa44", fontsize=12)

# Prozessor (rechts)
x_proc = x_base + (len(values_1)-1)*(width+0.12) + width
ax.arrow(x_proc, y1+height/2, 1, 0, head_width=0.23, head_length=0.22, fc='#cc3333', ec='#cc3333', lw=2, length_includes_head=True)
ax.text(x_proc+1.15, y1+height/2, "Prozessor", ha="left", va="center", color='#cc3333', fontsize=12)

# Zeichne zweite Warteschlange
for i, val in enumerate(values_2):
    x = x_base + i * (width + 0.12)
    rect = plt.Rectangle((x, y2), width, height, fill=True, edgecolor='black', facecolor='#e6ffe6', zorder=2)
    ax.add_patch(rect)
    ax.text(x + width/2, y2 + height/2, str(val), ha='center', va='center', fontsize=12, zorder=3)
# Prozessor (rechts)
x_proc = x_base + (len(values_1)-1)*(width+0.12) + width
ax.arrow(x_proc, y2+height/2, 1, 0, head_width=0.23, head_length=0.22, fc='#cc3333', ec='#cc3333', lw=2, length_includes_head=True)
ax.text(x_proc+1.15, y2+height/2, "Prozessor", ha="left", va="center", color='#cc3333', fontsize=12)


# Pfeil von Job 1 oben zu Job 1 hinten unten
x_job1_bot = x_base + 0 * (width + 0.12) + width/2
x_job1_top = x_base + (len(values_1) -1) * (width + 0.12) + width/2
ax.arrow(x_job1_top, y1-0.1, x_job1_bot-x_job1_top+0.2, y2+height/2-y1+0.6, head_width=0.23, head_length=0.22, fc='#2222aa', ec='#2222aa', lw=2, length_includes_head=True)
ax.text((x_job1_top+x_job1_bot)*0.75, (y1+y2+height/2)/2, "Job 1 wird (wenn nicht fertig) \n wieder hinten angestellt", ha='center', va='center', color='#2222aa', fontsize=11)

# Titel
plt.text(3.5, 4.5, "Job-Warteschlange (Queue): FIFO-Prinzip", fontsize=14, ha='center')
plt.tight_layout()
plt.savefig("job_queue_visualization.png")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_xlim(-1, 10)
ax.set_ylim(0, 7)
ax.axis('off')

# Werte in der Queue
values = ['Job 1', 'Job 2', 'Job 3', 'Job 4', 'Job 5']
width = 1
height = 0.7
y_queue = 4
x_base = 1

# Zeichne JOb-Queue 
for i, val in enumerate(values):
    x = x_base + i * (width + 0.13)
    rect = plt.Rectangle((x, y_queue), width, height, fill=True, edgecolor='black', facecolor='#cce6ff', zorder=2)
    ax.add_patch(rect)
    ax.text(x + width/2, y_queue + height/2, str(val), ha='center', va='center', fontsize=12, zorder=3)


# Zeichne Arbeiter als Kreise (rechts vom Förderband, übereinander)
n_workers = 3
worker_x = x_base + (len(values)-1)*(width+0.13) + 3.2
worker_ys = [y_queue-0.9 + i*1.2 for i in range(n_workers)]
for i, y in enumerate(worker_ys):
    circ = plt.Circle((worker_x, y), 0.5, color='#ffd699', ec='black', zorder=10)
    ax.add_patch(circ)
    ax.text(worker_x, y, f"Arbeiter {i+1}", ha='center', va='center', fontsize=11, zorder=11)
    # Pfeil vom Förderband zu Worker
    ax.arrow(x_base + (len(values)-1)*(width+0.13) + width+0.2, y_queue+height/2, 
             worker_x-(x_base + (len(values)-1)*(width+0.13)+2), y-y_queue-height/2,
             head_width=0.2, head_length=0.22, fc='#cc3333', ec='#cc3333', lw=2, length_includes_head=True)

#zeichne Förderband unterhalb der Jobs
# Förderband unterhalb der Jobs
band_x = x_base - 0.3
band_y = 3
band_width = (width + 0.13) * len(values) + 0.3
band_height = 0.5
band = FancyBboxPatch((band_x, band_y), band_width, band_height,
                      boxstyle="round,pad=0.3,rounding_size=0.5", 
                      edgecolor='#555555', facecolor='#f5f5f5', lw=2, zorder=1)
ax.add_patch(band)

# Kreise auf dem Förderband
n_items = 7
for i in range(n_items):
    circle_x = band_x + 0.2 + i * ((band_width-0.3)/(n_items-1))
    circle_y = band_y + band_height/2
    circle = plt.Circle((circle_x, circle_y), 0.32, color='#b3d9ff', ec='black', zorder=5)
    ax.add_patch(circle)
# Pfeil für ankommende Jobs (links)
ax.arrow(x_base-1, y_queue + height/2, 0.9, 0, head_width=0.23, head_length=0.22, fc='#44aa44', ec='#44aa44', lw=2, length_includes_head=True)
ax.text(x_base-1.1, y_queue + height/2, "arriving jobs", ha="right", va="center", color="#44aa44", fontsize=12)

plt.text(x_base + (len(values)-1)*(width+0.13)/2, 1.6*y_queue, "Queue als Förderband", fontsize=16, ha='center')
plt.tight_layout()
plt.savefig("queue_as_conveyor_belt.png")
plt.show()

# %% [markdown]
# # Heap

# %%
import matplotlib.pyplot as plt
radius = 0.4
def draw_heap(ax, nodes, edges, highlight=None, new_node=None, title="", bubble_up_path=None, arrow_label=None, arrow_color='#44aa44'):
    for idx, (x, y, val) in enumerate(nodes):
        if new_node is not None and idx == new_node:
            color = '#ffbb33'  # Orange für neuen Knoten
        elif highlight is not None and idx in highlight:
            color = '#ffd699'  # Gelb für z.B. Root
        else:
            color = '#cce6ff'
        circ = plt.Circle((x, y), radius, color=color, ec='black', zorder=10)
        ax.add_patch(circ)
        ax.text(x, y, str(val), ha='center', va='center', fontsize=12, zorder=11)
    for i, j in edges:
        x0, y0, _ = nodes[i]
        x1, y1, _ = nodes[j]
        ax.plot([x0, x1], [y0, y1], color='black', lw=2, zorder=5)
    ax.set_title(title, fontsize=16)
    ax.axis('off')
    if bubble_up_path:
        for a_idx, b_idx in zip(bubble_up_path[:-1], bubble_up_path[1:]):
            x0, y0, _ = nodes[a_idx]
            x1, y1, _ = nodes[b_idx]
            arrow = FancyArrowPatch((x0, y0+radius), (x1+radius, y1),
                                    connectionstyle="arc3,rad=0.3",
                                    arrowstyle="simple,tail_width=0.5,head_width=8,head_length=8",
                                    lw=2, color=arrow_color, zorder=12)
            ax.add_patch(arrow)
    # Label an den mittleren Pfeil
    if arrow_label:
        mid_idx = bubble_up_path[len(bubble_up_path)//2]
        x, y, _ = nodes[mid_idx]
        ax.text(x, y+1, arrow_label, color=arrow_color, fontsize=14, ha='center')
fig, axes = plt.subplots(1, 1, figsize=(15, 6))
# Heap-Layout für drei Ebenen (vollständiger Binärbaum mit 15 Knoten)
y_levels = [0, -1.7, -3.4, -5.1]
x_positions = [
    [7],                                 # Ebene 0: Root
    [3, 11],                             # Ebene 1
    [1, 5, 9, 13],                       # Ebene 2
    [0, 2, 4, 6, 8, 10, 12, 14]          # Ebene 3
]
values = [80, 60, 70, 50, 55, 65, 68, 40, 45, 53, 54, 63, 64, 66, 90]  # Beispielwerte, Heap-Eigenschaft grob beibehalten

nodes = []
for level, y in enumerate(y_levels):
    for i, x in enumerate(x_positions[level]):
        idx = sum(len(x_positions[j]) for j in range(level)) + i
        nodes.append((x, y, values[idx]))

edges = []
for parent in range(len(nodes)):
    left = 2*parent + 1
    right = 2*parent + 2
    if left < len(nodes):
        edges.append((parent, left))
    if right < len(nodes):
        edges.append((parent, right))

#Insertion mit Bubble Up (neuer Knoten ist 14)
draw_heap(
    axes, nodes, edges, 
    new_node=14,
    title="Insertion (bubble up)",
    bubble_up_path=[14, 6, 2, 0],  # Von neuem Knoten nach oben zur Root
    arrow_label="bubble up",
    arrow_color='#44aa44'
)



plt.tight_layout()
plt.savefig("heap_insertion_bubble_up.png")
plt.show()

# %%
radius = 0.4
def draw_heap(ax, nodes, edges, highlight=None, trickledown_path=None, arrow_label=None, arrow_color='#cc3333'):
    for idx, (x, y, val) in enumerate(nodes):
        if highlight is not None and idx in highlight:
            color = '#ffd699'  # Gelb für markierten Knoten (z.B. Root)
        else:
            color = '#cce6ff'
        circ = plt.Circle((x, y), radius, color=color, ec='black', zorder=10)
        ax.add_patch(circ)
        ax.text(x, y, str(val), ha='center', va='center', fontsize=12, zorder=11)
    for i, j in edges:
        x0, y0, _ = nodes[i]
        x1, y1, _ = nodes[j]
        ax.plot([x0, x1], [y0, y1], color='black', lw=2, zorder=5)
    ax.set_title("Deletion (trickledown)", fontsize=16)
    ax.axis('off')
    # Trickledown: mehrere geschwungene Pfeile
    if trickledown_path:
        for a_idx, b_idx in zip(trickledown_path[:-1], trickledown_path[1:]):
            x0, y0, _ = nodes[a_idx]
            x1, y1, _ = nodes[b_idx]
            arrow = FancyArrowPatch((x0, y0-radius), (x1, y1+radius),
                                    connectionstyle="arc3,rad=-0.3",
                                    arrowstyle="simple,tail_width=0.5,head_width=8,head_length=8",
                                    lw=2, color=arrow_color, zorder=12)
            ax.add_patch(arrow)
    # Label an den mittleren Pfeil
    if arrow_label and trickledown_path:
        mid_idx = trickledown_path[len(trickledown_path)//2]
        x, y, _ = nodes[mid_idx]
        ax.text(x, y-1, arrow_label, color=arrow_color, fontsize=14, ha='center')

fig, ax = plt.subplots(figsize=(15, 6))
# Heap-Layout für drei Ebenen (vollständiger Binärbaum mit 15 Knoten)
y_levels = [0, -1.7, -3.4, -5.1]
x_positions = [
    [7],                                 # Ebene 0: Root
    [3, 11],                             # Ebene 1
    [1, 5, 9, 13],                       # Ebene 2
    [0, 2, 4, 6, 8, 10, 12, 14]          # Ebene 3
]
values = [52, 70, 69, 50, 55, 65, 68, 40, 45, 53, 54, 63, 64, 66, 67]  # Beispielwerte, Heap-Eigenschaft grob beibehalten

nodes = []
for level, y in enumerate(y_levels):
    for i, x in enumerate(x_positions[level]):
        idx = sum(len(x_positions[j]) for j in range(level)) + i
        nodes.append((x, y, values[idx]))

edges = []
for parent in range(len(nodes)):
    left = 2*parent + 1
    right = 2*parent + 2
    if left < len(nodes):
        edges.append((parent, left))
    if right < len(nodes):
        edges.append((parent, right))

# Trickledown-Pfad z.B. von Root zu Kind, dann weiter zu Blatt
trickledown_path = [0, 1, 4, 10]  # Beispielpfad
draw_heap(
    ax, nodes, edges, 
    highlight=[0],
    trickledown_path=trickledown_path,
    arrow_label="trickledown",
    arrow_color='#cc3333'
)

plt.tight_layout()
plt.savefig("heap_deletion_trickledown.png")
plt.show()

# %%
N = np.arange(1, 1025, 1)
h = np.log2(N)

plt.figure(figsize=(8, 5))
plt.plot(N, h, color="#1a73e8", lw=2)
plt.xlabel("Anzahl der Elemente (N)")
plt.ylabel("Heap-Höhe (h)")
plt.title("Die Höhe eines vollständigen Binärbaums wächst logarithmisch mit der Elementanzahl")
plt.grid(True, alpha=0.3)
plt.text(300, 2, r"$h = O(\log N)$", fontsize=14, color="#1a73e8")
plt.tight_layout()
plt.savefig("heap_height_logarithmic.png")
plt.show()

# %%
levels = 4
nodes_per_level = [2**i for i in range(levels)]
y_coords = [-i for i in range(levels)]
x_coords = []
idxs = []
for lvl, n in enumerate(nodes_per_level):
    xs = np.linspace(0, 2**levels, n+2)[1:-1]
    x_coords += list(xs)
    idxs += [i for i in range(len(x_coords)-n, len(x_coords))]

fig, ax = plt.subplots(figsize=(10, 7))
ax.set_xlim(-1, 2**levels+1)
ax.set_ylim(-levels-1, 2)
ax.axis('off')

nodes = []
idx = 0
for lvl in range(levels):
    for i in range(nodes_per_level[lvl]):
        x = x_coords[idx]
        y = y_coords[lvl]
        # Blätter: keine Kinder
        if lvl == levels-1:
            color = '#cce6ff'
        else:
            color = '#ffd699'  # innere Knoten
        circ = plt.Circle((x, y), 0.32, color=color, ec='black', zorder=10)
        ax.add_patch(circ)
        ax.text(x, y, str(idx), ha='center', va='center', fontsize=11, zorder=11)
        nodes.append((x, y))
        idx += 1

# Kanten zeichnen
for parent in range(sum(nodes_per_level)):
    left = 2*parent + 1
    right = 2*parent + 2
    if left < sum(nodes_per_level):
        x0, y0 = nodes[parent]
        x1, y1 = nodes[left]
        ax.plot([x0, x1], [y0, y1], color='black', lw=2, zorder=5)
    if right < sum(nodes_per_level):
        x0, y0 = nodes[parent]
        x1, y1 = nodes[right]
        ax.plot([x0, x1], [y0, y1], color='black', lw=2, zorder=5)

plt.text(nodes[0][0], 1.3, 
         "Heapify: Trickledown von jedem inneren Knoten (gelb)\nnach oben zur Wurzel", 
         fontsize=14, ha='center', color="#cc3333")

# Listendarstellung der Knoten unterhalb des Baumes
rect_width = 0.7
rect_height = 0.5
y_rect = y_coords[-1] - 1.3
total_nodes = sum(nodes_per_level)
n_leaves = nodes_per_level[-1]
n_inner = total_nodes - n_leaves
x_base = x_coords[8]

for i in range(total_nodes):
    # Rechtecke werden in Baum-X-Koordinaten angeordnet
    x = x_base + i * rect_width
    if i < n_inner:
        color = '#ffd699'  # Gelb für innere Knoten
    else:
        color = '#cce6ff'  # Blau für Blätter (Randknoten)
    rect = plt.Rectangle((x, y_rect), rect_width, rect_height, facecolor=color, edgecolor='black', zorder=12)
    ax.add_patch(rect)
    ax.text(x + rect_width/2, y_rect + rect_height/2, str(i), ha='center', va='center', fontsize=11, zorder=13)

# Labels
ax.text(x_base, y_rect + rect_height+0.1, "Innere Knoten", ha='center', fontsize=12, color='#b8860b')
ax.text(x_base + (n_inner+1) * rect_width, y_rect + rect_height + 0.1, "Blätter", ha='center', fontsize=12, color='#1a73e8')

ax.text(x_base, y_rect - 0.7,"Hinweis: Zahlen bezeichnen die Indizes der Knoten im Array.\n Nicht die Werte (values) der Knoten.", ha='left', fontsize=11)

plt.tight_layout()
plt.savefig("heap_innernodes_leaves.png", bbox_inches='tight') 
plt.show()
